# %% [markdown]
# ### Hash Table generate unique index for each elements, make query faster.
# ### Like dictionary structure for example, if key value is index, we make it faster to insert and search and delete element.
# #### In python, dictionary plays the role of hash tables:
# #### - Key value is generated by hash function
# #### - Order of dictionary elements is not fixed
#
# #### Time complexity for searching in hash table is O(1)
